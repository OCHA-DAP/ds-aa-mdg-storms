# %% [markdown]
# # Historical Validation using Meteo-France Best Track Data

# %% [markdown]
# Using CERF allocation, people affected and testing out Scenarios 2 and 3.

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2

# %%
import geopandas as gpd
import pandas as pd
from pathlib import Path
from shapely.geometry import LineString, Point
import os
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from src import constants

# %%
# loading all actual cyclone tracks
cyclone_tracks = pd.read_csv(
    Path(constants.AA_DATA_DIR)
    / "private"
    / "raw"
    / "moz"
    / "rsmc"
    / "data_cyclone_SWIO_19851986_to_20222023.csv"
)

# %%
cerf_emdat = pd.read_csv(
    Path(constants.AA_DATA_DIR)
    / "public/exploration/mdg/cerf_emdat_bngrc_data.csv"
)

# %%
cerf_emdat[cerf_emdat["Nom"] == "BATSIRAI"]
# Out:
#          Nom  Total Affected - EMDAT  Sinistres  CERF Allocations
# 56  BATSIRAI                112115.0   166671.0         4476918.0

# %%
cyclone_tracks["Lat"] = cyclone_tracks["Lat"].apply(
    lambda x: -x if x > 0 else x
)
cyclone_tracks.loc[:, "Season"] = cyclone_tracks.apply(
    lambda x: (
        f"{x['Year'] - 1}-{x['Year']}"
        if x["Month"] <= 6
        else f"{x['Year']}-{x['Year'] + 1}"
    ),
    axis=1,
)
# Ensure UTC is formatted as a two-digit hour
cyclone_tracks["UTC"] = cyclone_tracks["UTC"].apply(lambda x: f"{int(x):02}")
# Create a datetime column from separate date and time columns
cyclone_tracks["ISO_TIME"] = pd.to_datetime(
    cyclone_tracks[["Year", "Month", "Day", "UTC"]]
    .astype(str)
    .agg(" ".join, axis=1)
)

# %%
# Create 'geometry' column in cyclone_tracks GeoDataFrame using Lat/Lon for the points
cyclone_tracks["geometry"] = cyclone_tracks.apply(
    lambda row: Point(row["Lon"], row["Lat"]), axis=1
)

# Convert cyclone_tracks DataFrame to GeoDataFrame
cyclone_tracks_gdf = gpd.GeoDataFrame(
    cyclone_tracks, geometry="geometry", crs="EPSG:4326"
)
cyclone_tracks_buffer = cyclone_tracks.copy()
cyclone_tracks_buffer["RMW_km"] = cyclone_tracks_buffer["RMW (mn)"] * 1.852
cyclone_tracks_buffer["RMW_km"] = (
    cyclone_tracks_buffer["RMW_km"].fillna(1).replace(0, 1)
)
# Create 'geometry' column in cyclone_tracks_buffer GeoDataFrame
cyclone_tracks_buffer["geometry"] = cyclone_tracks_buffer.apply(
    lambda row: Point(row["Lon"], row["Lat"]), axis=1
)

# Convert cyclone_tracks_buffer DataFrame to GeoDataFrame
cyclone_tracks_gdf_buffer = gpd.GeoDataFrame(
    cyclone_tracks_buffer, geometry="geometry", crs="EPSG:4326"
)

# Create buffers for the cyclone tracks using the RMW_km column, converting km to degrees

# Create buffer around gdf_adm0 with the given distance
# Reproject to a CRS that uses meters
cyclone_tracks_gdf_buffer = cyclone_tracks_gdf_buffer.to_crs(
    epsg=constants.mdg_epsg
)

# Apply the buffer
cyclone_tracks_gdf_buffer["geometry"] = (
    cyclone_tracks_gdf_buffer.geometry.buffer(
        cyclone_tracks_gdf_buffer["RMW_km"] * 1000
    )
)

# Reproject back to the original CRS
cyclone_tracks_gdf_buffer = cyclone_tracks_gdf_buffer.to_crs(
    cyclone_tracks_gdf.crs
)

# %%
cyclone_tracks[cyclone_tracks["Name"] == "EMNATI"]["Max wind (kt)"].unique()
# Out:
# array([25., 30., 27., 33., 40., 43., 53., 60., 62., 70., 80., 85., 95.,
#        78., 75., 50., 45., 48., 35., 20.])

# %%
cyclone_tracks[cyclone_tracks["Name"] == "BATSIRAI"]["Max wind (kt)"].unique()
# Out:
# array([ 20.,  22.,  23.,  25.,  28.,  30.,  40.,  50.,  60.,  85.,  nan,
#         45.,  65.,  80.,  90.,  95.,  70., 100., 110.,  35.,  32.,  37.,
#         43.,  47.,  42.])

# %%
adm0_path = (
    Path(constants.AA_DATA_DIR)
    / "public"
    / "raw"
    / "mdg"
    / "cod_ab"
    / "mdg_admbnda_adm0_BNGRC_OCHA_20181031.shp"
)
gdf_adm0 = gpd.read_file(adm0_path)

# %%
# Create buffer around gdf_adm0 with the given distance
# Reproject to a CRS that uses meters (e.g., EPSG:3857)
gdf_adm0_buffer = gdf_adm0.to_crs(epsg=constants.mdg_epsg)

# Apply the buffer of 100 km (100,000 meters)
gdf_adm0_buffer["geometry"] = gdf_adm0_buffer.geometry.buffer(
    constants.buffer * 1000
)  # 100 km = 100,000 meters

# Reproject back to the original CRS
gdf_adm0_buffer = gdf_adm0_buffer.to_crs(gdf_adm0.crs)

# %%
cyclone_tracks_sel = gpd.sjoin(
    cyclone_tracks_gdf_buffer,
    gdf_adm0_buffer,
    how="inner",
    predicate="intersects",
)
cyclone_tracks_sel = cyclone_tracks_sel.sort_values("ISO_TIME")
cyclone_tracks_sel_2006 = cyclone_tracks_sel[
    cyclone_tracks_sel["Year"] >= 2006
]

# %%
cyclone_tracks_sel_nobuff = gpd.sjoin(
    cyclone_tracks_gdf_buffer, gdf_adm0, how="inner", predicate="intersects"
)
cyclone_tracks_sel_nobuff = cyclone_tracks_sel_nobuff.sort_values("ISO_TIME")
cyclone_tracks_sel_2006_nobuff = cyclone_tracks_sel_nobuff[
    cyclone_tracks_sel_nobuff["Year"] >= 2006
]

# %%
cyclones_since_2006 = cyclone_tracks_sel_2006[
    cyclone_tracks_sel_2006["Max wind (kt)"] >= 48
]["Name"].unique()

# %%
# which storms are met for Scenario 2 and 3
scenario2_storms = cyclone_tracks_sel_2006[
    cyclone_tracks_sel_2006["Max wind (kt)"] >= 64
]["Name"].unique()
scenario3_storms = cyclone_tracks_sel_2006[
    cyclone_tracks_sel_2006["Max wind (kt)"] >= 90
]["Name"].unique()
pd.DataFrame(scenario3_storms).to_csv(
    Path(
        constants.AA_DATA_DIR,
        "public",
        "exploration",
        "mdg",
        "scenario3_storms_mfr_best_track.csv",
    ),
    index=False,
    header=False,
)

# %%
# Scenario 2.5
scenario2_point_5_storms = np.union1d(
    cyclone_tracks_sel_2006_nobuff[
        cyclone_tracks_sel_2006_nobuff["Max wind (kt)"] >= 64
    ]["Name"].unique(),
    scenario3_storms,
)

# %%
cerf_emdat.columns
# Out:
# Index(['Nom', 'Total Affected - EMDAT', 'Sinistres', 'CERF Allocations'], dtype='object')

# %%
# adding year and season to output
cerf_emdat_df = cerf_emdat.merge(
    cyclone_tracks_sel_2006[["Name", "Year", "Season"]].drop_duplicates(),
    left_on="Nom",
    right_on="Name",
    how="right",
)

# %%
cerf_emdat_df = cerf_emdat_df[cerf_emdat_df["Name"].isin(cyclones_since_2006)]
cerf_emdat_df
# Out:
#          Nom  Total Affected - EMDAT  Sinistres  CERF Allocations      Name  \
# 1   BOLOETSE                     NaN     6537.0               NaN  BOLOETSE
# 3      BONDO                     NaN   184998.0               NaN     BONDO
# 4     CLOVIS                  7313.0        NaN               NaN    CLOVIS
# 6        NaN                     NaN        NaN               NaN     FAVIO
# 7    INDLALA                215198.0  1740911.0         1230903.0   INDLALA
# 8       JAYA                     NaN    74091.0         2200650.0      JAYA
# 10      FAME                  8613.0    17530.0               NaN      FAME
# 11      IVAN                524153.0   487146.0         4625583.0      IVAN
# 12     JOKWE                   400.0      586.0               NaN     JOKWE
# 15    FANELE                     NaN        NaN               NaN    FANELE
# 16    IZILDA                  3376.0        NaN               NaN    IZILDA
# 17      JADE                 64918.0    60818.0               NaN      JADE
# 21    HUBERT                192132.0        NaN               NaN    HUBERT
# 22      JOEL                     NaN        NaN               NaN      JOEL
# 23   BINGIZA                115215.0   267099.0               NaN   BINGIZA
# 28  GIOVANNA                250284.0   247014.0         1999893.0  GIOVANNA
# 29     IRINA                 85015.0        NaN               NaN     IRINA
# 31       NaN                     NaN        NaN               NaN   FELLENG
# 32    HARUNA                 40281.0    41655.0         3003483.0    HARUNA
# 36    HELLEN                  1736.0        NaN               NaN    HELLEN
# 37    CHEDZA                174007.0        NaN               NaN    CHEDZA
# 42     ENAWO                434253.0   437443.0         4999601.0     ENAWO
# 43       AVA                161318.0   161328.0               NaN       AVA
# 44       NaN                     NaN        NaN               NaN  DUMAZILE
# 45   ELIAKIM                 50872.0        NaN               NaN   ELIAKIM
# 47      IDAI                  1100.0        NaN               NaN      IDAI
# 49     BELNA                 20293.0     2996.0               NaN     BELNA
# 52    HEROLD                  3200.0        NaN               NaN    HEROLD
# 54    ELOISE                  1000.0        NaN               NaN    ELOISE
# 57  BATSIRAI                112115.0   166671.0         4476918.0  BATSIRAI
# 59    EMNATI                169000.0   172178.0         1470268.0    EMNATI
# 60     GOMBE                   900.0      935.0               NaN     GOMBE
# 61   JASMINE                  4800.0        NaN               NaN   JASMINE
# 62   CHENESO                 90870.0    90519.0               NaN   CHENESO
# 63    FREDDY                299000.0   189352.0         7033283.0    FREDDY
#
#     Year     Season
# 1   2006  2005-2006
# 3   2006  2006-2007
# 4   2007  2006-2007
# 6   2007  2006-2007
# 7   2007  2006-2007
# 8   2007  2006-2007
# 10  2008  2007-2008
# 11  2008  2007-2008
# 12  2008  2007-2008
# 15  2009  2008-2009
# 16  2009  2008-2009
# 17  2009  2008-2009
# 21  2010  2009-2010
# 22  2010  2009-2010
# 23  2011  2010-2011
# 28  2012  2011-2012
# 29  2012  2011-2012
# 31  2013  2012-2013
# 32  2013  2012-2013
# 36  2014  2013-2014
# 37  2015  2014-2015
# 42  2017  2016-2017
# 43  2018  2017-2018
# 44  2018  2017-2018
# 45  2018  2017-2018
# 47  2019  2018-2019
# 49  2019  2019-2020
# 52  2020  2019-2020
# 54  2021  2020-2021
# 57  2022  2021-2022
# 59  2022  2021-2022
# 60  2022  2021-2022
# 61  2022  2021-2022
# 62  2023  2022-2023
# 63  2023  2022-2023

# %%
cerf_emdat_df["Scenario 2"] = [
    storm in scenario2_storms for storm in cerf_emdat_df["Name"]
]
cerf_emdat_df["Scenario 3"] = [
    storm in scenario3_storms for storm in cerf_emdat_df["Name"]
]
cerf_emdat_df["Scenario 2.5"] = [
    storm in scenario2_point_5_storms for storm in cerf_emdat_df["Name"]
]
df = cerf_emdat_df[
    [
        "Name",
        "Season",
        "Scenario 2",
        # "Scenario 2.5",
        "Scenario 3",
        "Total Affected - EMDAT",
        "Sinistres",
        "CERF Allocations",
    ]
]

# Sort the DataFrame by 'Total Affected' in descending order
# Round values in 'Total Affected' and 'CERF Allocations' columns
df_sorted = df.sort_values(by="Total Affected - EMDAT", ascending=False)


# Define functions for highlighting and coloring bars
def highlight_true(val):
    color = "red" if val else ""
    return f"background-color: {color}"


def color_bar_affected(val):
    if isinstance(val, (int, float)) and not pd.isna(val):
        return f'background: linear-gradient(90deg, orange {val/df_sorted["Total Affected - EMDAT"].max()*100}%, transparent {val/df_sorted["Total Affected - EMDAT"].max()*100}%);'
    return ""


def color_bar_sinistres(val):
    if isinstance(val, (int, float)) and not pd.isna(val):
        return f'background: linear-gradient(90deg, #FFD700 {val/df_sorted["Sinistres"].max()*100}%, transparent {val/df_sorted["Sinistres"].max()*100}%);'
    return ""


def color_bar_cerf(val):
    if isinstance(val, (int, float)) and not pd.isna(val):
        return f'background: linear-gradient(90deg, green {val/df_sorted["CERF Allocations"].max()*100}%, transparent {val/df_sorted["CERF Allocations"].max()*100}%);'
    return ""


# Apply styling
styled_df = (
    df_sorted.style.map(
        highlight_true,
        subset=[
            "Scenario 2",
            # "Scenario 2.5",
            "Scenario 3",
        ],
    )
    .map(color_bar_affected, subset=["Total Affected - EMDAT"])
    .map(color_bar_sinistres, subset=["Sinistres"])
    .map(color_bar_cerf, subset=["CERF Allocations"])
    .format(
        {
            "Total Affected - EMDAT": lambda x: (
                f"{int(x):,}" if pd.notna(x) else ""
            ),  # Format with commas, no decimals, NaN as blank
            "Sinistres": lambda x: (
                f"{int(x):,}" if pd.notna(x) else ""
            ),  # Format with commas, no decimals, NaN as blank
            "CERF Allocations": lambda x: (
                f"{int(x):,}" if pd.notna(x) else ""
            ),  # Format with commas, no decimals, NaN as blank
        }
    )
    .set_table_styles(
        {"": [{"selector": "table", "props": "background-color: white;"}]}
    )
)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_6cdf5 table.col-1 {
#   background-color: white;
# }
# #T_6cdf5_row0_col2, #T_6cdf5_row0_col3, #T_6cdf5_row1_col2, #T_6cdf5_row1_col3, #T_6cdf5_row2_col2, #T_6cdf5_row3_col2, #T_6cdf5_row4_col2, #T_6cdf5_row4_col3, #T_6cdf5_row7_col2, #T_6cdf5_row8_col2, #T_6cdf5_row9_col2, #T_6cdf5_row10_col2, #T_6cdf5_row10_col3, #T_6cdf5_row11_col2, #T_6cdf5_row15_col2, #T_6cdf5_row16_col2, #T_6cdf5_row17_col2, #T_6cdf5_row22_col2, #T_6cdf5_row22_col3, #T_6cdf5_row23_col2, #T_6cdf5_row23_col3, #T_6cdf5_row27_col2, #T_6cdf5_row28_col2, #T_6cdf5_row29_col2, #T_6cdf5_row30_col2, #T_6cdf5_row31_col2, #T_6cdf5_row31_col3, #T_6cdf5_row33_col2 {
#   background-color: red;
# }
# #T_6cdf5_row0_col4 {
#   background: linear-gradient(90deg, orange 100.0%, transparent 100.0%);
# }
# #T_6cdf5_row0_col5 {
#   background: linear-gradient(90deg, #FFD700 27.982246076910304%, transparent 27.982246076910304%);
# }
# #T_6cdf5_row0_col6 {
#   background: linear-gradient(90deg, green 65.76705359360628%, transparent 65.76705359360628%);
# }
# #T_6cdf5_row1_col4 {
#   background: linear-gradient(90deg, orange 82.84851942085612%, transparent 82.84851942085612%);
# }
# #T_6cdf5_row1_col5 {
#   background: linear-gradient(90deg, #FFD700 25.12724659675308%, transparent 25.12724659675308%);
# }
# #T_6cdf5_row1_col6 {
#   background: linear-gradient(90deg, green 71.08488311930573%, transparent 71.08488311930573%);
# }
# #T_6cdf5_row2_col3, #T_6cdf5_row3_col3, #T_6cdf5_row5_col2, #T_6cdf5_row5_col3, #T_6cdf5_row6_col2, #T_6cdf5_row6_col3, #T_6cdf5_row7_col3, #T_6cdf5_row8_col3, #T_6cdf5_row9_col3, #T_6cdf5_row11_col3, #T_6cdf5_row12_col2, #T_6cdf5_row12_col3, #T_6cdf5_row13_col2, #T_6cdf5_row13_col3, #T_6cdf5_row14_col2, #T_6cdf5_row14_col3, #T_6cdf5_row15_col3, #T_6cdf5_row16_col3, #T_6cdf5_row17_col3, #T_6cdf5_row18_col2, #T_6cdf5_row18_col3, #T_6cdf5_row19_col2, #T_6cdf5_row19_col3, #T_6cdf5_row20_col2, #T_6cdf5_row20_col3, #T_6cdf5_row21_col2, #T_6cdf5_row21_col3, #T_6cdf5_row24_col2, #T_6cdf5_row24_col3, #T_6cdf5_row25_col2, #T_6cdf5_row25_col3, #T_6cdf5_row26_col2, #T_6cdf5_row26_col3, #T_6cdf5_row27_col3, #T_6cdf5_row28_col3, #T_6cdf5_row29_col3, #T_6cdf5_row30_col3, #T_6cdf5_row32_col2, #T_6cdf5_row32_col3, #T_6cdf5_row33_col3, #T_6cdf5_row34_col2, #T_6cdf5_row34_col3 {
#   background-color: ;
# }
# #T_6cdf5_row2_col4 {
#   background: linear-gradient(90deg, orange 57.04441260471656%, transparent 57.04441260471656%);
# }
# #T_6cdf5_row2_col5 {
#   background: linear-gradient(90deg, #FFD700 10.876604260642846%, transparent 10.876604260642846%);
# }
# #T_6cdf5_row2_col6 {
#   background: linear-gradient(90deg, green 100.0%, transparent 100.0%);
# }
# #T_6cdf5_row3_col4 {
#   background: linear-gradient(90deg, orange 47.7501798139093%, transparent 47.7501798139093%);
# }
# #T_6cdf5_row3_col5 {
#   background: linear-gradient(90deg, #FFD700 14.188778174185815%, transparent 14.188778174185815%);
# }
# #T_6cdf5_row3_col6 {
#   background: linear-gradient(90deg, green 28.434701120372946%, transparent 28.434701120372946%);
# }
# #T_6cdf5_row4_col4 {
#   background: linear-gradient(90deg, orange 41.05633278832707%, transparent 41.05633278832707%);
# }
# #T_6cdf5_row4_col5 {
#   background: linear-gradient(90deg, #FFD700 100.0%, transparent 100.0%);
# }
# #T_6cdf5_row4_col6 {
#   background: linear-gradient(90deg, green 17.50111576627871%, transparent 17.50111576627871%);
# }
# #T_6cdf5_row5_col4 {
#   background: linear-gradient(90deg, orange 36.655709306252184%, transparent 36.655709306252184%);
# }
# #T_6cdf5_row6_col4 {
#   background: linear-gradient(90deg, orange 33.197749512069954%, transparent 33.197749512069954%);
# }
# #T_6cdf5_row7_col4 {
#   background: linear-gradient(90deg, orange 32.242494080926754%, transparent 32.242494080926754%);
# }
# #T_6cdf5_row7_col5 {
#   background: linear-gradient(90deg, #FFD700 9.89010925888802%, transparent 9.89010925888802%);
# }
# #T_6cdf5_row7_col6 {
#   background: linear-gradient(90deg, green 20.90443396064114%, transparent 20.90443396064114%);
# }
# #T_6cdf5_row8_col4 {
#   background: linear-gradient(90deg, orange 30.776891480159417%, transparent 30.776891480159417%);
# }
# #T_6cdf5_row8_col5 {
#   background: linear-gradient(90deg, #FFD700 9.266872344421973%, transparent 9.266872344421973%);
# }
# #T_6cdf5_row9_col4 {
#   background: linear-gradient(90deg, orange 21.981177251680332%, transparent 21.981177251680332%);
# }
# #T_6cdf5_row9_col5 {
#   background: linear-gradient(90deg, #FFD700 15.342484480826418%, transparent 15.342484480826418%);
# }
# #T_6cdf5_row10_col4 {
#   background: linear-gradient(90deg, orange 21.389746886882264%, transparent 21.389746886882264%);
# }
# #T_6cdf5_row10_col5 {
#   background: linear-gradient(90deg, #FFD700 9.57378062405258%, transparent 9.57378062405258%);
# }
# #T_6cdf5_row10_col6 {
#   background: linear-gradient(90deg, green 63.653318087726596%, transparent 63.653318087726596%);
# }
# #T_6cdf5_row11_col4 {
#   background: linear-gradient(90deg, orange 17.336541048129074%, transparent 17.336541048129074%);
# }
# #T_6cdf5_row11_col5 {
#   background: linear-gradient(90deg, #FFD700 5.199519102355031%, transparent 5.199519102355031%);
# }
# #T_6cdf5_row12_col4 {
#   background: linear-gradient(90deg, orange 16.219500794615314%, transparent 16.219500794615314%);
# }
# #T_6cdf5_row13_col4 {
#   background: linear-gradient(90deg, orange 12.385314974826054%, transparent 12.385314974826054%);
# }
# #T_6cdf5_row13_col5 {
#   background: linear-gradient(90deg, #FFD700 3.4934583100457175%, transparent 3.4934583100457175%);
# }
# #T_6cdf5_row14_col4 {
#   background: linear-gradient(90deg, orange 9.705563070324887%, transparent 9.705563070324887%);
# }
# #T_6cdf5_row15_col4 {
#   background: linear-gradient(90deg, orange 7.684969846590595%, transparent 7.684969846590595%);
# }
# #T_6cdf5_row15_col5 {
#   background: linear-gradient(90deg, #FFD700 2.3927127808371593%, transparent 2.3927127808371593%);
# }
# #T_6cdf5_row15_col6 {
#   background: linear-gradient(90deg, green 42.70385536882278%, transparent 42.70385536882278%);
# }
# #T_6cdf5_row16_col4 {
#   background: linear-gradient(90deg, orange 3.871579481563589%, transparent 3.871579481563589%);
# }
# #T_6cdf5_row16_col5 {
#   background: linear-gradient(90deg, #FFD700 0.17209380605901162%, transparent 0.17209380605901162%);
# }
# #T_6cdf5_row17_col4 {
#   background: linear-gradient(90deg, orange 1.6432224941953972%, transparent 1.6432224941953972%);
# }
# #T_6cdf5_row17_col5 {
#   background: linear-gradient(90deg, #FFD700 1.0069440654921475%, transparent 1.0069440654921475%);
# }
# #T_6cdf5_row18_col4 {
#   background: linear-gradient(90deg, orange 1.395203308957499%, transparent 1.395203308957499%);
# }
# #T_6cdf5_row19_col4 {
#   background: linear-gradient(90deg, orange 0.9157631454937776%, transparent 0.9157631454937776%);
# }
# #T_6cdf5_row20_col4 {
#   background: linear-gradient(90deg, orange 0.644086745663957%, transparent 0.644086745663957%);
# }
# #T_6cdf5_row21_col4 {
#   background: linear-gradient(90deg, orange 0.6105087636625184%, transparent 0.6105087636625184%);
# }
# #T_6cdf5_row22_col4 {
#   background: linear-gradient(90deg, orange 0.33120100428691623%, transparent 0.33120100428691623%);
# }
# #T_6cdf5_row23_col4 {
#   background: linear-gradient(90deg, orange 0.20986238750899067%, transparent 0.20986238750899067%);
# }
# #T_6cdf5_row24_col4 {
#   background: linear-gradient(90deg, orange 0.190783988644537%, transparent 0.190783988644537%);
# }
# #T_6cdf5_row25_col4 {
#   background: linear-gradient(90deg, orange 0.1717055897800833%, transparent 0.1717055897800833%);
# }
# #T_6cdf5_row25_col5 {
#   background: linear-gradient(90deg, #FFD700 0.05370751290559942%, transparent 0.05370751290559942%);
# }
# #T_6cdf5_row26_col4 {
#   background: linear-gradient(90deg, orange 0.0763135954578148%, transparent 0.0763135954578148%);
# }
# #T_6cdf5_row26_col5 {
#   background: linear-gradient(90deg, #FFD700 0.03366053750019386%, transparent 0.03366053750019386%);
# }
# #T_6cdf5_row27_col5 {
#   background: linear-gradient(90deg, #FFD700 0.375493060817009%, transparent 0.375493060817009%);
# }
# #T_6cdf5_row28_col5 {
#   background: linear-gradient(90deg, #FFD700 10.626505318192601%, transparent 10.626505318192601%);
# }
# #T_6cdf5_row30_col5 {
#   backgrou
