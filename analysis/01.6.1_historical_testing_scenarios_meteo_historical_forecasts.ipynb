# %% [markdown]
# # Historical Validation

# %% [markdown]
# Using CERF allocation, people affected and testing out Scenarios 2 and 3.

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2
# Out:
# The jupyter_black extension is already loaded. To reload it, use:
#   %reload_ext jupyter_black
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import geopandas as gpd
import pandas as pd
from pathlib import Path
from shapely.geometry import LineString
import os
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from src.datasources import codab, rsmc
from src import constants

# %%
df_rsmc = rsmc.load_historical_forecast_distances()
distance_cols = [x for x in df_rsmc.columns if "_distance_km" in x]
df_rsmc["any_distance_km"] = df_rsmc[distance_cols].min(axis=1)

# %%
cerf_emdat_df = pd.read_csv(
    Path(constants.AA_DATA_DIR)
    / "public/exploration/mdg/cerf_emdat_bngrc_data.csv"
)

# %%
cerf_emdat_df[cerf_emdat_df["Nom"] == "BATSIRAI"]
# Out:
#          Nom  Total Affected - EMDAT  Sinistres  CERF Allocations
# 56  BATSIRAI                112115.0   166671.0         4476918.0

# %%
adm1_path = (
    Path(constants.AA_DATA_DIR)
    / "public"
    / "raw"
    / "mdg"
    / "cod_ab"
    / "mdg_admbnda_adm1_BNGRC_OCHA_20181031.shp"
)
gdf_adm1 = gpd.read_file(adm1_path)
gdf_adm1_sel = gdf_adm1[gdf_adm1["ADM1_EN"].isin(constants.ADMS)]

# %%
# Create buffer around gdf_adm1 with the given distance
# Reproject to a CRS that uses meters (e.g., EPSG:3857)
gdf_adm1_buffer = gdf_adm1_sel.to_crs(epsg=constants.mdg_epsg)

# Apply the buffer of 100 km (100,000 meters)
gdf_adm1_buffer["geometry"] = gdf_adm1_buffer.geometry.buffer(
    100 * 1000
)  # 100 km = 100,000 meters

# Reproject back to the original CRS
gdf_adm1_buffer = gdf_adm1_buffer.to_crs(gdf_adm1.crs)

# %% [markdown]
# which storms are met for Scenario 2 and 3

# %%
from shapely.geometry import Point

gdf_rsmc = gpd.GeoDataFrame(
    df_rsmc,
    geometry=[
        Point(lon, lat)
        for lon, lat in zip(df_rsmc["longitude"], df_rsmc["latitude"])
    ],
    crs="EPSG:4326",
)
storms_within_aoi = gpd.sjoin(
    gdf_rsmc, gdf_adm1_buffer, how="inner", predicate="intersects"
)["name"].unique()
storms_onland = gpd.sjoin(
    gdf_rsmc, gdf_adm1_sel, how="inner", predicate="intersects"
)["name"].unique()

# %%
storms_within_aoi
# Out:
# array(['ANAIS', '0120132014', 'ABELA', 'AVA', 'ANA', 'ALVARO', 'BELNA',
#        'BATSIRAI', 'CHALANE', 'DUMAKO', 'BINGIZA', 'CHANDA', 'EMNATI',
#        'CHENESO', 'DANDO', 'CHEDZA', 'ENAWO', 'DIANE', 'FELLENG',
#        'ELIAKIM', 'ELOISE', 'FREDDY', 'ELEANOR', '0820132014', 'FANTALA',
#        'FRANCISCO', 'FILIPO', 'GIOVANNA', 'HARUNA', 'GOMBE', 'GAMANE',
#        'HEROLD', 'IRINA', '1120142015', 'HALIBA', 'JASMINE', 'HELLEN',
#        'IMAN'], dtype=object)

# %%
# Scenario 2
# Readiness
scenario2_storms_readiness = df_rsmc[
    (df_rsmc["name"].isin(storms_within_aoi))
    & (df_rsmc["MG_distance_km"] <= 100)
    & (df_rsmc["max_wind_kt"] >= 64)
    & (df_rsmc["lt_hour"].between(72, 120))
]["name"].unique()
scenario2_storms_action = df_rsmc[
    (df_rsmc["name"].isin(storms_within_aoi))
    & (df_rsmc["MG_distance_km"] <= 100)
    & (df_rsmc["max_wind_kt"] >= 64)
    & (df_rsmc["lt_hour"].between(0, 72))
]["name"].unique()

# %%
# Scenario 3
# Readiness
scenario3_storms_readiness = df_rsmc[
    (df_rsmc["name"].isin(storms_within_aoi))
    & (df_rsmc["MG_distance_km"] <= 100)
    & (df_rsmc["max_wind_kt"] >= 90)
    & (df_rsmc["lt_hour"].between(72, 120))
]["name"].unique()
scenario3_storms_action = df_rsmc[
    (df_rsmc["name"].isin(storms_within_aoi))
    & (df_rsmc["MG_distance_km"] <= 100)
    & (df_rsmc["max_wind_kt"] >= 90)
    & (df_rsmc["lt_hour"].between(0, 72))
]["name"].unique()

# %%
# Scenario 2.5
scenario2_point_5_storms_readiness = df_rsmc[
    (
        (df_rsmc["name"].isin(storms_within_aoi))
        & (df_rsmc["MG_distance_km"] <= 100)
        & (df_rsmc["max_wind_kt"] >= 90)
        & (df_rsmc["lt_hour"].between(72, 120))
    )
    | (
        (df_rsmc["name"].isin(storms_onland))
        & (df_rsmc["MG_distance_km"] == 0)
        & (df_rsmc["max_wind_kt"] >= 64)
        & (df_rsmc["lt_hour"].between(72, 120))
    )
]["name"].unique()
scenario2_point_5_storms_action = df_rsmc[
    (
        (df_rsmc["name"].isin(storms_within_aoi))
        & (df_rsmc["MG_distance_km"] <= 100)
        & (df_rsmc["max_wind_kt"] >= 90)
        & (df_rsmc["lt_hour"].between(0, 72))
    )
    | (
        (df_rsmc["name"].isin(storms_onland))
        & (df_rsmc["MG_distance_km"] == 0)
        & (df_rsmc["max_wind_kt"] >= 64)
        & (df_rsmc["lt_hour"].between(0, 72))
    )
]["name"].unique()

# %%
cerf_emdat_df.columns
# Out:
# Index(['Nom', 'Total Affected - EMDAT', 'Sinistres', 'CERF Allocations'], dtype='object')

# %%
df_rsmc.columns
# Out:
# Index(['valid_time', 'lt_hour', 'latitude', 'longitude', 'max_wind_kt',
#        'season', 'name', 'numberseason', 'issue_time', 'MG_distance_km',
#        'any_distance_km'],
#       dtype='object')

# %%
# adding year and season to output
cerf_emdat_df = cerf_emdat_df.merge(
    df_rsmc[["name", "season"]].drop_duplicates(),
    left_on="Nom",
    right_on="name",
    how="left",
)

# %%
cerf_emdat_df = cerf_emdat_df[cerf_emdat_df["Nom"].isin(storms_within_aoi)]
cerf_emdat_df
# Out:
#           Nom  Total Affected - EMDAT  Sinistres  CERF Allocations       name  \
# 34    BINGIZA                115215.0   267099.0               NaN    BINGIZA
# 36     CHANDA                     NaN        NaN               NaN     CHANDA
# 37      DANDO                     NaN        NaN               NaN      DANDO
# 38   GIOVANNA                250284.0   247014.0         1999893.0   GIOVANNA
# 39      IRINA                 85015.0        NaN               NaN      IRINA
# 40     HARUNA                 40281.0    41655.0         3003483.0     HARUNA
# 43     HELLEN                  1736.0        NaN               NaN     HELLEN
# 44     CHEDZA                174007.0        NaN               NaN     CHEDZA
# 46      ENAWO                434253.0   437443.0         4999601.0      ENAWO
# 47        AVA                161318.0   161328.0               NaN        AVA
# 48    ELIAKIM                 50872.0        NaN               NaN    ELIAKIM
# 50      BELNA                 20293.0     2996.0               NaN      BELNA
# 51  FRANCISCO                     NaN        NaN               NaN  FRANCISCO
# 52     HEROLD                  3200.0        NaN               NaN     HEROLD
# 53    CHALANE                     NaN        NaN               NaN    CHALANE
# 54     ELOISE                  1000.0        NaN               NaN     ELOISE
# 55       IMAN                     NaN        NaN               NaN       IMAN
# 56   BATSIRAI                112115.0   166671.0         4476918.0   BATSIRAI
# 57     DUMAKO                  9900.0        NaN               NaN     DUMAKO
# 58     EMNATI                169000.0   172178.0         1470268.0     EMNATI
# 59        ANA                131555.0        NaN               NaN        ANA
# 60      GOMBE                   900.0      935.0               NaN      GOMBE
# 61    JASMINE                  4800.0        NaN               NaN    JASMINE
# 62    CHENESO                 90870.0    90519.0               NaN    CHENESO
# 63     FREDDY                299000.0   189352.0         7033283.0     FREDDY
# 64     ALVARO                 25837.0        NaN               NaN     ALVARO
# 65     GAMANE                 89469.0    89465.0         3000000.0     GAMANE
#
#       season
# 34  20102011
# 36  20112012
# 37  20112012
# 38  20112012
# 39  20112012
# 40  20122013
# 43  20132014
# 44  20142015
# 46  20162017
# 47  20172018
# 48  20172018
# 50  20192020
# 51  20192020
# 52  20192020
# 53  20202021
# 54  20202021
# 55  20202021
# 56  20212022
# 57  20212022
# 58  20212022
# 59  20212022
# 60  20212022
# 61  20212022
# 62  20222023
# 63  20222023
# 64  20232024
# 65  20232024

# %%
cerf_emdat_df["Scenario 2 - Readiness"] = [
    storm in scenario2_storms_readiness for storm in cerf_emdat_df["Nom"]
]
cerf_emdat_df["Scenario 2 - Action"] = [
    storm in scenario2_storms_action for storm in cerf_emdat_df["Nom"]
]
cerf_emdat_df["Scenario 2.5 - Readiness"] = [
    storm in scenario2_point_5_storms_readiness
    for storm in cerf_emdat_df["Nom"]
]
cerf_emdat_df["Scenario 2.5 - Action"] = [
    storm in scenario2_point_5_storms_action for storm in cerf_emdat_df["Nom"]
]
cerf_emdat_df["Scenario 3 - Readiness"] = [
    storm in scenario3_storms_readiness for storm in cerf_emdat_df["Nom"]
]
cerf_emdat_df["Scenario 3 - Action"] = [
    storm in scenario3_storms_action for storm in cerf_emdat_df["Nom"]
]
df = cerf_emdat_df[
    [
        "Nom",
        "season",
        "Scenario 2 - Readiness",
        "Scenario 2 - Action",
        "Scenario 2.5 - Readiness",
        "Scenario 2.5 - Action",
        "Scenario 3 - Readiness",
        "Scenario 3 - Action",
        "Total Affected - EMDAT",
        "Sinistres",
        "CERF Allocations",
    ]
]

# Sort the DataFrame by 'Total Affected' in descending order
# Round values in 'Total Affected' and 'CERF Allocations' columns
df_sorted = df.sort_values(by="Total Affected - EMDAT", ascending=False)


# Define functions for highlighting and coloring bars
def highlight_true(val):
    color = "red" if val else ""
    return f"background-color: {color}"


def color_bar_affected(val):
    if isinstance(val, (int, float)) and not pd.isna(val):
        return f'background: linear-gradient(90deg, orange {val/df_sorted["Total Affected - EMDAT"].max()*100}%, transparent {val/df_sorted["Total Affected - EMDAT"].max()*100}%);'
    return ""


def color_bar_sinistres(val):
    if isinstance(val, (int, float)) and not pd.isna(val):
        return f'background: linear-gradient(90deg, #FFD700 {val/df_sorted["Sinistres"].max()*100}%, transparent {val/df_sorted["Sinistres"].max()*100}%);'
    return ""


def color_bar_cerf(val):
    if isinstance(val, (int, float)) and not pd.isna(val):
        return f'background: linear-gradient(90deg, green {val/df_sorted["CERF Allocations"].max()*100}%, transparent {val/df_sorted["CERF Allocations"].max()*100}%);'
    return ""


# Apply styling
styled_df = (
    df_sorted.style.map(
        highlight_true,
        subset=[
            "Scenario 2 - Readiness",
            "Scenario 2 - Action",
            "Scenario 2.5 - Readiness",
            "Scenario 2.5 - Action",
            "Scenario 3 - Readiness",
            "Scenario 3 - Action",
        ],
    )
    .map(color_bar_affected, subset=["Total Affected - EMDAT"])
    .map(color_bar_sinistres, subset=["Sinistres"])
    .map(color_bar_cerf, subset=["CERF Allocations"])
    .format(
        {
            "season": lambda x: (x if pd.notna(x) else ""),
            "Total Affected - EMDAT": lambda x: (
                f"{int(x):,}" if pd.notna(x) else ""
            ),  # Format with commas, no decimals, NaN as blank
            "Sinistres": lambda x: (
                f"{int(x):,}" if pd.notna(x) else ""
            ),  # Format with commas, no decimals, NaN as blank
            "CERF Allocations": lambda x: (
                f"{int(x):,}" if pd.notna(x) else ""
            ),  # Format with commas, no decimals, NaN as blank
        }
    )
    .set_table_styles(
        {"": [{"selector": "table", "props": "background-color: white;"}]}
    )
)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_4d669 table.col-1 {
#   background-color: white;
# }
# #T_4d669_row0_col2, #T_4d669_row0_col3, #T_4d669_row0_col4, #T_4d669_row0_col5, #T_4d669_row0_col6, #T_4d669_row0_col7, #T_4d669_row1_col2, #T_4d669_row1_col3, #T_4d669_row1_col4, #T_4d669_row1_col5, #T_4d669_row1_col6, #T_4d669_row1_col7, #T_4d669_row2_col2, #T_4d669_row2_col3, #T_4d669_row2_col4, #T_4d669_row2_col5, #T_4d669_row2_col6, #T_4d669_row2_col7, #T_4d669_row4_col2, #T_4d669_row4_col3, #T_4d669_row4_col4, #T_4d669_row4_col5, #T_4d669_row4_col6, #T_4d669_row4_col7, #T_4d669_row5_col3, #T_4d669_row5_col5, #T_4d669_row7_col2, #T_4d669_row7_col3, #T_4d669_row7_col4, #T_4d669_row7_col5, #T_4d669_row7_col7, #T_4d669_row8_col2, #T_4d669_row8_col3, #T_4d669_row8_col4, #T_4d669_row8_col5, #T_4d669_row8_col6, #T_4d669_row8_col7, #T_4d669_row10_col2, #T_4d669_row10_col3, #T_4d669_row10_col4, #T_4d669_row10_col5, #T_4d669_row10_col6, #T_4d669_row10_col7, #T_4d669_row12_col3, #T_4d669_row12_col5, #T_4d669_row13_col2, #T_4d669_row13_col3, #T_4d669_row13_col5, #T_4d669_row13_col7, #T_4d669_row15_col2, #T_4d669_row15_col3, #T_4d669_row15_col4, #T_4d669_row15_col5, #T_4d669_row15_col6, #T_4d669_row15_col7, #T_4d669_row19_col3, #T_4d669_row19_col5, #T_4d669_row19_col7 {
#   background-color: red;
# }
# #T_4d669_row0_col8 {
#   background: linear-gradient(90deg, orange 100.0%, transparent 100.0%);
# }
# #T_4d669_row0_col9 {
#   background: linear-gradient(90deg, #FFD700 100.0%, transparent 100.0%);
# }
# #T_4d669_row0_col10 {
#   background: linear-gradient(90deg, green 71.08488311930573%, transparent 71.08488311930573%);
# }
# #T_4d669_row1_col8 {
#   background: linear-gradient(90deg, orange 68.85387090014346%, transparent 68.85387090014346%);
# }
# #T_4d669_row1_col9 {
#   background: linear-gradient(90deg, #FFD700 43.28609670288472%, transparent 43.28609670288472%);
# }
# #T_4d669_row1_col10 {
#   background: linear-gradient(90deg, green 100.0%, transparent 100.0%);
# }
# #T_4d669_row2_col8 {
#   background: linear-gradient(90deg, orange 57.635525834018416%, transparent 57.635525834018416%);
# }
# #T_4d669_row2_col9 {
#   background: linear-gradient(90deg, #FFD700 56.467699791744295%, transparent 56.467699791744295%);
# }
# #T_4d669_row2_col10 {
#   background: linear-gradient(90deg, green 28.434701120372946%, transparent 28.434701120372946%);
# }
# #T_4d669_row3_col2, #T_4d669_row3_col3, #T_4d669_row3_col4, #T_4d669_row3_col5, #T_4d669_row3_col6, #T_4d669_row3_col7, #T_4d669_row5_col2, #T_4d669_row5_col4, #T_4d669_row5_col6, #T_4d669_row5_col7, #T_4d669_row6_col2, #T_4d669_row6_col3, #T_4d669_row6_col4, #T_4d669_row6_col5, #T_4d669_row6_col6, #T_4d669_row6_col7, #T_4d669_row7_col6, #T_4d669_row9_col2, #T_4d669_row9_col3, #T_4d669_row9_col4, #T_4d669_row9_col5, #T_4d669_row9_col6, #T_4d669_row9_col7, #T_4d669_row11_col2, #T_4d669_row11_col3, #T_4d669_row11_col4, #T_4d669_row11_col5, #T_4d669_row11_col6, #T_4d669_row11_col7, #T_4d669_row12_col2, #T_4d669_row12_col4, #T_4d669_row12_col6, #T_4d669_row12_col7, #T_4d669_row13_col4, #T_4d669_row13_col6, #T_4d669_row14_col2, #T_4d669_row14_col3, #T_4d669_row14_col4, #T_4d669_row14_col5, #T_4d669_row14_col6, #T_4d669_row14_col7, #T_4d669_row16_col2, #T_4d669_row16_col3, #T_4d669_row16_col4, #T_4d669_row16_col5, #T_4d669_row16_col6, #T_4d669_row16_col7, #T_4d669_row17_col2, #T_4d669_row17_col3, #T_4d669_row17_col4, #T_4d669_row17_col5, #T_4d669_row17_col6, #T_4d669_row17_col7, #T_4d669_row18_col2, #T_4d669_row18_col3, #T_4d669_row18_col4, #T_4d669_row18_col5, #T_4d669_row18_col6, #T_4d669_row18_col7, #T_4d669_row19_col2, #T_4d669_row19_col4, #T_4d669_row19_col6, #T_4d669_row20_col2, #T_4d669_row20_col3, #T_4d669_row20_col4, #T_4d669_row20_col5, #T_4d669_row20_col6, #T_4d669_row20_col7, #T_4d669_row21_col2, #T_4d669_row21_col3, #T_4d669_row21_col4, #T_4d669_row21_col5, #T_4d669_row21_col6, #T_4d669_row21_col7, #T_4d669_row22_col2, #T_4d669_row22_col3, #T_4d669_row22_col4, #T_4d669_row22_col5, #T_4d669_row22_col6, #T_4d669_row22_col7, #T_4d669_row23_col2, #T_4d669_row23_col3, #T_4d669_row23_col4, #T_4d669_row23_col5, #T_4d669_row23_col6, #T_4d669_row23_col7, #T_4d669_row24_col2, #T_4d669_row24_col3, #T_4d669_row24_col4, #T_4d669_row24_col5, #T_4d669_row24_col6, #T_4d669_row24_col7, #T_4d669_row25_col2, #T_4d669_row25_col3, #T_4d669_row25_col4, #T_4d669_row25_col5, #T_4d669_row25_col6, #T_4d669_row25_col7, #T_4d669_row26_col2, #T_4d669_row26_col3, #T_4d669_row26_col4, #T_4d669_row26_col5, #T_4d669_row26_col6, #T_4d669_row26_col7 {
#   background-color: ;
# }
# #T_4d669_row3_col8 {
#   background: linear-gradient(90deg, orange 40.07041977833198%, transparent 40.07041977833198%);
# }
# #T_4d669_row4_col8 {
#   background: linear-gradient(90deg, orange 38.917405291385435%, transparent 38.917405291385435%);
# }
# #T_4d669_row4_col9 {
#   background: linear-gradient(90deg, #FFD700 39.36009948724748%, transparent 39.36009948724748%);
# }
# #T_4d669_row4_col10 {
#   background: linear-gradient(90deg, green 20.90443396064114%, transparent 20.90443396064114%);
# }
# #T_4d669_row5_col8 {
#   background: linear-gradient(90deg, orange 37.14839045441252%, transparent 37.14839045441252%);
# }
# #T_4d669_row5_col9 {
#   background: linear-gradient(90deg, #FFD700 36.87977633657414%, transparent 36.87977633657414%);
# }
# #T_4d669_row6_col8 {
#   background: linear-gradient(90deg, orange 30.29455179353971%, transparent 30.29455179353971%);
# }
# #T_4d669_row7_col8 {
#   background: linear-gradient(90deg, orange 26.531768347023508%, transparent 26.531768347023508%);
# }
# #T_4d669_row7_col9 {
#   background: linear-gradient(90deg, #FFD700 61.05915513564053%, transparent 61.05915513564053%);
# }
# #T_4d669_row8_col8 {
#   background: linear-gradient(90deg, orange 25.81789878250697%, transparent 25.81789878250697%);
# }
# #T_4d669_row8_col9 {
#   background: linear-gradient(90deg, #FFD700 38.101192612523235%, transparent 38.101192612523235%);
# }
# #T_4d669_row8_col10 {
#   background: linear-gradient(90deg, green 63.653318087726596%, transparent 63.653318087726596%);
# }
# #T_4d669_row9_col8 {
#   background: linear-gradient(90deg, orange 20.925589460521863%, transparent 20.925589460521863%);
# }
# #T_4d669_row9_col9 {
#   background: linear-gradient(90deg, #FFD700 20.692753112977005%, transparent 20.692753112977005%);
# }
# #T_4d669_row10_col8 {
#   background: linear-gradient(90deg, orange 20.602966473461322%, transparent 20.602966473461322%);
# }
# #T_4d669_row10_col9 {
#   background: linear-gradient(90deg, #FFD700 20.451807435483023%, transparent 20.451807435483023%);
# }
# #T_4d669_row10_col10 {
#   background: linear-gradient(90deg, green 42.65433368741169%, transparent 42.65433368741169%);
# }
# #T_4d669_row11_col8 {
#   background: linear-gradient(90deg, orange 19.577297105604334%, transparent 19.577297105604334%);
# }
# #T_4d669_row12_col8 {
#   background: linear-gradient(90deg, orange 11.714829834221065%, transparent 11.714829834221065%);
# }
# #T_4d669_row13_col8 {
#   background: linear-gradient(90deg, orange 9.275929009126017%, transparent 9.275929009126017%);
# }
# #T_4d669_row13_col9 {
#   background: linear-gradient(90deg, #FFD700 9.522383487677253%, transparent 9.522383487677253%);
# }
# #T_4d669_row13_col10 {
#   background: linear-gradient(90deg, green 42.70385536882278%, transparent 42.70385536882278%);
# }
# #T_4d669_row14_col8 {
#   background: linear-gradient(90deg, orange 5.949757399488317%, transparent 5.949757399488317%);
# }
# #T_4d669_row15_col8 {
#   background: linear-gradient(90deg, orange 4.673082281527128%, transparent 4.673082281527128%);
# }
# #T_4d669_row15_col9 {
#   background: linear-gradient(90deg, #FFD700 0.6848892312827043%, transparent 0.6848892312827043%);
# }
# #T_4d669_row16_col8 {
#   background: linear-gradient(90deg, orange 2.2797769963592653%, transparent 2.2797769963592653%);
# }
# #T_4d669_row17_col8 {
#   background: linear-gradient(90deg, orange 1.1053464224772194%, transparent 1.1053464224772194%);
# }
# #T_4d669_row18_col8 {
#   background: linear-gradient(90deg, orange 0.736897614984813%, transparent 0.736897614984813%);
# }
# #T_4d669_row19_col8 {
#   background: linear-gradient(90deg, orange 0.399766956129261%, transparent 0.3997
